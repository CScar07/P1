# %%
import sys
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spotify_data_path = ""

# %%
spotify_data = pd.read_csv(spotify_data_path)

# %%
spotify_data
# Out:
#          Unnamed: 0      artist_name                         track_name  \
# 0                 0       Jason Mraz                    I Won't Give Up
# 1                 1       Jason Mraz                   93 Million Miles
# 2                 2    Joshua Hyslop                   Do Not Let Me Go
# 3                 3     Boyce Avenue                           Fast Car
# 4                 4     Andrew Belle                   Sky's Still Blue
# ...             ...              ...                                ...
# 1159759     1473391     Nicola Conte                      Black Spirits
# 1159760     1473392     Nicola Conte                         Quiet Dawn
# 1159761     1473393       Amon Tobin                  Morning Ms Candis
# 1159762     1473394  Peace Orchestra      Happy Christmas (War Is Over)
# 1159763     1473395     Mo' Horizons  Hit the Road Jack (Pé Na Éstrada)
#
#                        track_id  popularity  year     genre  danceability  \
# ...

# %%
spotify_data['length'] = spotify_data['duration_ms'] / 60000

# %%
spotify_clean = spotify_data.drop(['track_id', 'duration_ms','Unnamed: 0','valence','key', 'mode', 'liveness', 'time_signature'], axis=1)

# %%
spotify_clean
# Out:
#              artist_name                         track_name  popularity  year  \
# 0             Jason Mraz                    I Won't Give Up          68  2012
# 1             Jason Mraz                   93 Million Miles          50  2012
# 2          Joshua Hyslop                   Do Not Let Me Go          57  2012
# 3           Boyce Avenue                           Fast Car          58  2012
# 4           Andrew Belle                   Sky's Still Blue          54  2012
# ...                  ...                                ...         ...   ...
# 1159759     Nicola Conte                      Black Spirits           4  2011
# 1159760     Nicola Conte                         Quiet Dawn           3  2011
# 1159761       Amon Tobin                  Morning Ms Candis           2  2011
# 1159762  Peace Orchestra      Happy Christmas (War Is Over)           0  2011
# 1159763     Mo' Horizons  Hit the Road Jack (Pé Na Éstrada)           3  2011
#
# ...

# %%
spotify_clean.describe()
# Out:
#          popularity          year  danceability        energy      loudness  \
# count  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06
# mean   1.838312e+01  2.011955e+03  5.374382e-01  6.396699e-01 -8.981353e+00
# std    1.588554e+01  6.803901e+00  1.844780e-01  2.705009e-01  5.682215e+00
# min    0.000000e+00  2.000000e+03  0.000000e+00  0.000000e+00 -5.810000e+01
# 25%    5.000000e+00  2.006000e+03  4.130000e-01  4.540000e-01 -1.082900e+01
# 50%    1.500000e+01  2.012000e+03  5.500000e-01  6.940000e-01 -7.450000e+00
# 75%    2.900000e+01  2.018000e+03  6.770000e-01  8.730000e-01 -5.276000e+00
# max    1.000000e+02  2.023000e+03  9.930000e-01  1.000000e+00  6.172000e+00
#
#         speechiness  acousticness  instrumentalness         tempo  \
# count  1.159764e+06  1.159764e+06      1.159764e+06  1.159764e+06
# mean   9.281477e-02  3.215370e-01      2.523489e-01  1.213771e+02
# std    1.268409e-01  3.549872e-01      3.650731e-01  2.977975e+01
# ...

# %%
spotify_clean[spotify_clean['popularity'] >= 85 ]['popularity'].count()
# Out:
# 105

# %%
popular_data = spotify_clean[spotify_clean['popularity'] >= 85]

# %%
popular_data.describe()
# Out:
#        popularity         year  danceability      energy    loudness  \
# count  105.000000   105.000000    105.000000  105.000000  105.000000
# mean    87.819048  2019.761905      0.652314    0.640699   -6.190152
# std      2.908148     4.535170      0.149928    0.169444    3.140224
# min     85.000000  2000.000000      0.000000    0.003420  -28.460000
# 25%     85.000000  2019.000000      0.559000    0.534000   -7.081000
# 50%     87.000000  2022.000000      0.662000    0.675000   -5.529000
# 75%     90.000000  2022.000000      0.768000    0.755000   -4.309000
# max    100.000000  2023.000000      0.949000    0.965000   -2.724000
#
#        speechiness  acousticness  instrumentalness       tempo      length
# count   105.000000    105.000000        105.000000  105.000000  105.000000
# mean      0.075159      0.253846          0.013344  122.431067    3.383427
# std       0.072004      0.246324          0.099519   29.996479    0.727166
# ...
